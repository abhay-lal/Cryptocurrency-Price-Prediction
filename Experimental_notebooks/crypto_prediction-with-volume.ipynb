# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c g-research-crypto-forecasting
# Out:
# ...
# competition.cpython-37m-x86_64-linux-gnu.so: Skipping, found more recently modified local copy (use --force to force download)
# __init__.py: Skipping, found more recently modified local copy (use --force to force download)
# example_sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# example_test.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# supplemental_train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# asset_details.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: train.csv

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('/content/train.csv')

# %%
df
# Out:
#            timestamp  Asset_ID  Count  ...        Volume          VWAP    Target
# 0         1514764860         2   40.0  ...  1.923301e+01   2373.116392 -0.004218
# 1         1514764860         0    5.0  ...  7.838000e+01      8.530000 -0.014399
# 2         1514764860         1  229.0  ...  3.155006e+01  13827.062093 -0.014643
# 3         1514764860         5   32.0  ...  6.626713e+03      7.657713 -0.013922
# 4         1514764860         7    5.0  ...  1.210873e+02     25.891363 -0.008264
# ...              ...       ...    ...  ...           ...           ...       ...
# 24236801  1632182400         9  775.0  ...  4.663725e+03    156.994319       NaN
# 24236802  1632182400        10   34.0  ...  3.975460e+00   2434.818747       NaN
# 24236803  1632182400        13  380.0  ...  2.193732e+06      0.091388       NaN
# 24236804  1632182400        12  177.0  ...  1.828508e+05      0.282134       NaN
# 24236805  1632182400        11   48.0  ...  1.035123e+02    232.569697       NaN
#
# ...

# %%
df.shape
# Out:
# (24236806, 10)

# %%
from datetime import datetime
df['date'] = pd.to_datetime(df['timestamp'], unit = 's')
df = df.sort_values('date')
groups = pd.factorize(df['date'].dt.day.astype(str) + '_' + df['date'].dt.month.astype(str) + '_' + df['date'].dt.year.astype(str))[0]

# %%
btc = df[df["Asset_ID"]==1].set_index("date")

# %%
btc
# Out:
#                       timestamp  Asset_ID  ...          VWAP    Target
# date                                       ...
# 2018-01-01 00:01:00  1514764860         1  ...  13827.062093 -0.014643
# 2018-01-01 00:02:00  1514764920         1  ...  13840.362591 -0.015037
# 2018-01-01 00:03:00  1514764980         1  ...  13806.068014 -0.010309
# 2018-01-01 00:04:00  1514765040         1  ...  13783.598101 -0.008999
# 2018-01-01 00:05:00  1514765100         1  ...  13735.586842 -0.008079
# ...                         ...       ...  ...           ...       ...
# 2021-09-20 23:56:00  1632182160         1  ...  42935.489499       NaN
# 2021-09-20 23:57:00  1632182220         1  ...  42879.576084       NaN
# 2021-09-20 23:58:00  1632182280         1  ...  42844.090693       NaN
# 2021-09-20 23:59:00  1632182340         1  ...  42935.761938       NaN
# 2021-09-21 00:00:00  1632182400         1  ...  43011.414052       NaN
#
# [1956282 rows x 10 columns]

# %%
btc.isna().sum()
# Out:
# timestamp      0
# Asset_ID       0
# Count          0
# Open           0
# High           0
# Low            0
# Close          0
# Volume         0
# VWAP           0
# Target       304
# dtype: int64

# %%
btc.describe
# Out:
# <bound method NDFrame.describe of                       timestamp  Asset_ID  ...          VWAP    Target
# date                                       ...
# 2018-01-01 00:01:00  1514764860         1  ...  13827.062093 -0.014643
# 2018-01-01 00:02:00  1514764920         1  ...  13840.362591 -0.015037
# 2018-01-01 00:03:00  1514764980         1  ...  13806.068014 -0.010309
# 2018-01-01 00:04:00  1514765040         1  ...  13783.598101 -0.008999
# 2018-01-01 00:05:00  1514765100         1  ...  13735.586842 -0.008079
# ...                         ...       ...  ...           ...       ...
# 2021-09-20 23:56:00  1632182160         1  ...  42935.489499       NaN
# 2021-09-20 23:57:00  1632182220         1  ...  42879.576084       NaN
# 2021-09-20 23:58:00  1632182280         1  ...  42844.090693       NaN
# 2021-09-20 23:59:00  1632182340         1  ...  42935.761938       NaN
# 2021-09-21 00:00:00  1632182400         1  ...  43011.414052       NaN
#
# [1956282 rows x 10 columns]>

# %%
import plotly.graph_objects as go

# %%
from datetime import datetime
from plotly.offline import iplot

# %%
btc_mini = btc.iloc[-200:]

# %%
fig = go.Figure(data=[go.Candlestick(x=btc_mini.index, open=btc_mini['Open'], high=btc_mini['High'], low=btc_mini['Low'], close=btc_mini['Close'])])

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="72971f5f-2ed3-40b5-870f-397cd5ce61a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("72971f5f-2ed3-40b5-870f-397cd5ce61a7")) {
#                     Plotly.newPlot(
#                         '72971f5f-2ed3-40b5-870f-397cd5ce61a7',
# ...

# %%
btc
# Out:
#                       timestamp  Asset_ID  ...          VWAP    Target
# date                                       ...
# 2018-01-01 00:01:00  1514764860         1  ...  13827.062093 -0.014643
# 2018-01-01 00:02:00  1514764920         1  ...  13840.362591 -0.015037
# 2018-01-01 00:03:00  1514764980         1  ...  13806.068014 -0.010309
# 2018-01-01 00:04:00  1514765040         1  ...  13783.598101 -0.008999
# 2018-01-01 00:05:00  1514765100         1  ...  13735.586842 -0.008079
# ...                         ...       ...  ...           ...       ...
# 2021-09-20 23:56:00  1632182160         1  ...  42935.489499       NaN
# 2021-09-20 23:57:00  1632182220         1  ...  42879.576084       NaN
# 2021-09-20 23:58:00  1632182280         1  ...  42844.090693       NaN
# 2021-09-20 23:59:00  1632182340         1  ...  42935.761938       NaN
# 2021-09-21 00:00:00  1632182400         1  ...  43011.414052       NaN
#
# [1956282 rows x 10 columns]

# %%
btc.dropna(axis=0,inplace=True)

# %%
btc.drop(columns=['timestamp','Asset_ID','Target'],axis=1,inplace=True)

# %%
btc
# Out:
#                       Count         Open  ...      Volume          VWAP
# date                                      ...
# 2018-01-01 00:01:00   229.0  13835.19400  ...   31.550062  13827.062093
# 2018-01-01 00:02:00   235.0  13835.03600  ...   31.046432  13840.362591
# 2018-01-01 00:03:00   528.0  13823.90000  ...   55.061820  13806.068014
# 2018-01-01 00:04:00   435.0  13802.51200  ...   38.780529  13783.598101
# 2018-01-01 00:05:00   742.0  13766.00000  ...  108.501637  13735.586842
# ...                     ...          ...  ...         ...           ...
# 2021-09-20 23:40:00  2643.0  42632.46500  ...  100.797218  42653.031385
# 2021-09-20 23:41:00  2281.0  42718.81500  ...   76.339988  42755.785162
# 2021-09-20 23:42:00  2642.0  42772.92125  ...  117.429123  42749.075916
# 2021-09-20 23:43:00  2134.0  42762.29000  ...   78.049458  42749.024591
# 2021-09-20 23:44:00  2165.0  42703.80250  ...   86.518794  42680.263993
#
# [1955978 rows x 7 columns]

# %%
print(list(btc))
# Out:
# ['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
btc[['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP']]=scaler.fit_transform(btc[['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP']])

# %%
btc
# Out:
#                         Count      Open      High  ...     Close    Volume      VWAP
# date                                               ...
# 2018-01-01 00:01:00  0.002606  0.173308  0.175573  ...  0.173519  0.003032  0.173158
# 2018-01-01 00:02:00  0.002675  0.173306  0.176196  ...  0.173161  0.002984  0.173373
# 2018-01-01 00:03:00  0.006024  0.173125  0.175356  ...  0.172726  0.005292  0.172817
# 2018-01-01 00:04:00  0.004961  0.172778  0.175333  ...  0.172186  0.003727  0.172453
# 2018-01-01 00:05:00  0.008471  0.172186  0.174635  ...  0.171487  0.010428  0.171674
# ...                       ...       ...       ...  ...       ...       ...       ...
# 2021-09-20 23:40:00  0.030202  0.640370  0.640927  ...  0.641486  0.009687  0.640751
# 2021-09-20 23:41:00  0.026064  0.641770  0.642263  ...  0.642756  0.007337  0.642418
# 2021-09-20 23:42:00  0.030191  0.642648  0.642388  ...  0.642329  0.011286  0.642309
# ...

# %%
y = btc['Close']
X = btc.drop(columns=['Close'],axis=1)
#btc=btc.values

# %%
btc
# Out:
#                         Count      Open      High  ...     Close    Volume      VWAP
# date                                               ...
# 2018-01-01 00:01:00  0.002606  0.173308  0.175573  ...  0.173519  0.003032  0.173158
# 2018-01-01 00:02:00  0.002675  0.173306  0.176196  ...  0.173161  0.002984  0.173373
# 2018-01-01 00:03:00  0.006024  0.173125  0.175356  ...  0.172726  0.005292  0.172817
# 2018-01-01 00:04:00  0.004961  0.172778  0.175333  ...  0.172186  0.003727  0.172453
# 2018-01-01 00:05:00  0.008471  0.172186  0.174635  ...  0.171487  0.010428  0.171674
# ...                       ...       ...       ...  ...       ...       ...       ...
# 2021-09-20 23:40:00  0.030202  0.640370  0.640927  ...  0.641486  0.009687  0.640751
# 2021-09-20 23:41:00  0.026064  0.641770  0.642263  ...  0.642756  0.007337  0.642418
# 2021-09-20 23:42:00  0.030191  0.642648  0.642388  ...  0.642329  0.011286  0.642309
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=0)
X_train=np.array(X_train)
y_train=np.array(y_train)
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 6, 50)             10400
#
#  lstm_4 (LSTM)               (None, 6, 50)             20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
btc
# Out:
#                         Count      Open      High  ...     Close    Volume      VWAP
# date                                               ...
# 2018-01-01 00:01:00  0.002606  0.173308  0.175573  ...  0.173519  0.003032  0.173158
# 2018-01-01 00:02:00  0.002675  0.173306  0.176196  ...  0.173161  0.002984  0.173373
# 2018-01-01 00:03:00  0.006024  0.173125  0.175356  ...  0.172726  0.005292  0.172817
# 2018-01-01 00:04:00  0.004961  0.172778  0.175333  ...  0.172186  0.003727  0.172453
# 2018-01-01 00:05:00  0.008471  0.172186  0.174635  ...  0.171487  0.010428  0.171674
# ...                       ...       ...       ...  ...       ...       ...       ...
# 2021-09-20 23:40:00  0.030202  0.640370  0.640927  ...  0.641486  0.009687  0.640751
# 2021-09-20 23:41:00  0.026064  0.641770  0.642263  ...  0.642756  0.007337  0.642418
# 2021-09-20 23:42:00  0.030191  0.642648  0.642388  ...  0.642329  0.011286  0.642309
# ...

# %%
model.fit(X_train,y_train,verbose=1,epochs=10,batch_size=128)
# Out:
# Epoch 1/10
# 12225/12225 [==============================] - 342s 28ms/step - loss: 1.4521e-05
# Epoch 2/10
# 12225/12225 [==============================] - 344s 28ms/step - loss: 2.1633e-06
# Epoch 3/10
# 12225/12225 [==============================] - 337s 28ms/step - loss: 1.3937e-06
# Epoch 4/10
# 12225/12225 [==============================] - 340s 28ms/step - loss: 1.1100e-06
# Epoch 5/10
# 12225/12225 [==============================] - 341s 28ms/step - loss: 9.9317e-07
# Epoch 6/10
# 12225/12225 [==============================] - 358s 29ms/step - loss: 9.4939e-07
# Epoch 7/10
# 12225/12225 [==============================] - 350s 29ms/step - loss: 8.5033e-07
# Epoch 8/10
# 12225/12225 [==============================] - 362s 30ms/step - loss: 7.6447e-07
# Epoch 9/10
# 12225/12225 [==============================] - 346s 28ms/step - loss: 7.2348e-07
# Epoch 10/10
# 12225/12225 [==============================] - 364s 30ms/step - loss: 6.8766e-07

# %%
model.save('/content/model_close.h5')

# %%
 losses=pd.DataFrame(model.history.history)
losses.plot()

# %%
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
y_test = np.array(y_test)

# %%
y_test = y_test.reshape(391196,1)
pred=model.predict(X_test)
rmse=np.sqrt(np.mean(((pred-y_test)**2)))
rmse
# Out:
# 0.0004691827360865989

# %%
rmse
# Out:
# 0.0004691827360865989
